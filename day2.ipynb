# %% [markdown]
# <a href="https://colab.research.google.com/github/pbxpanda/dw_matrix_road_sign/blob/master/day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter

# %%
cd '/content/drive/My Drive/Colab Notebooks/dw_matrix/matrix_three/dw_matrix_road_sign'
# Out:
# /content/drive/My Drive/Colab Notebooks/dw_matrix/matrix_three/dw_matrix_road_sign

# %%
ls data
# Out:
# signnames.csv  test.p  train.p

# %%
train = pd.read_pickle('data/train.p')
train.keys()
# Out:
# dict_keys(['coords', 'labels', 'features', 'sizes'])

# %%
X_train, y_train = train['features'], train['labels']
X_train.shape, y_train.shape
# Out:
# ((34799, 32, 32, 3), (34799,))

# %%
#RGB - Red Green Blue

# %%
plt.imshow(X_train[10000])

# %%
signs = pd.read_csv('data/signnames.csv')
signs.head()
# Out:
#    a                     b
# 0  0  Speed limit (20km/h)
# 1  1  Speed limit (30km/h)
# 2  2  Speed limit (50km/h)
# 3  3  Speed limit (60km/h)
# 4  4  Speed limit (70km/h)

# %%
dict_signs=signs.to_dict()['b']
dict_signs[30]
# Out:
# 'Beware of ice/snow'

# %%
for id_sign in dict_signs.keys():

  given_signs = X_train[y_train==id_sign]

  plt.figure(figsize=(15, 5))
  for i in range(9):
    plt.subplot('19{0}'.format(i+1))
    plt.imshow(given_signs[1])
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """

# %%
cnt = Counter(y_train).most_common()

cnt

# %%
id_labels, cnt_labels = zip(*cnt)
ids = range(len(id_labels))

plt.figure(figsize=(15,5))
plt.bar(ids,cnt_labels)

plt.xlabel('Znaki')
labels = [dict_signs[id_labels[id_]] for id_ in id_labels]
plt.xticks(ids,labels, rotation = 'vertical')
plt.title('Znaki drogowe - wystąpienia wg znaku')
plt.show()

# %%
id_labels[10]
# Out:
# 7

# %%
dict_signs[id_labels[10]]
# Out:
# 'Speed limit (100km/h)'
